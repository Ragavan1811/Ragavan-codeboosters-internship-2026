# %%
import pandas as pd
df=pd.read_csv("student_performance.csv")
df.head()
df.head(15)
# Out:
#     student_id           name  age  gender        department  semester  \
# 0         1001   Aarav Sharma   19    Male  Computer Science         2
# 1         1002    Priya Patel   20  Female  Computer Science         2
# 2         1003    Rohit Verma   19    Male       Electronics         2
# 3         1004    Sneha Reddy   20  Female        Mechanical         2
# 4         1005     Arjun Nair   19    Male  Computer Science         2
# 5         1006    Meera Joshi   20  Female       Electronics         2
# 6         1007    Kiran Kumar   21    Male             Civil         2
# 7         1008    Divya Singh   19  Female  Computer Science         2
# 8         1009   Rahul Mishra   20    Male        Mechanical         2
# 9         1010     Ananya Das   19  Female  Computer Science         2
# 10        1011    Vikram Iyer   20    Male       Electronics         2
# 11        1012    Pooja Gupta   19  Female             Civil         2
# ...

# %%
df.shape
# Out:
# (30, 13)

# %%
df.shape[0]
# Out:
# 30

# %%
df.tail()
# Out:
#     student_id            name  age  gender        department  semester  \
# 25        1026      Rekha Nair   20  Female       Electronics         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 27        1028   Sunita Pillai   19  Female             Civil         2
# 28        1029      Nitin Jain   20    Male        Mechanical         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 25          72             77             73                 63
# 26          84             79             75                 87
# 27          60             65             68                 39
# 28          75             76             70                 50
# 29          91             93             87                 94
#
#     attendance_percentage                city  admission_year
# 25                     82               Kochi            2023
# ...

# %%
print(df.columns.tolist())
# Out:
# ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year']

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.isnull()
# Out:
#     student_id   name    age  gender  department  semester  math_score  \
# 0        False  False  False   False       False     False       False
# 1        False  False  False   False       False     False       False
# 2        False  False  False   False       False     False       False
# 3        False  False  False   False       False     False       False
# 4        False  False  False   False       False     False       False
# 5        False  False  False   False       False     False       False
# 6        False  False  False   False       False     False       False
# 7        False  False  False   False       False     False       False
# 8        False  False  False   False       False     False       False
# 9        False  False  False   False       False     False       False
# 10       False  False  False   False       False     False       False
# 11       False  False  False   False       False     False       False
# ...

# %%
print(df['department'].unique())
# Out:
# ['Computer Science' 'Electronics' 'Mechanical' 'Civil']

# %%
print(df['department'].value_counts())
# Out:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# gender
# Male      15
# Female    15
# Name: count, dtype: int64

# %%
print(df['city'].value_counts())
# Out:
# city
# Kochi                 2
# Lucknow               2
# Thiruvananthapuram    2
# Agra                  2
# Kolkata               2
# Hyderabad             1
# Mumbai                1
# Delhi                 1
# Ahmedabad             1
# Varanasi              1
# Bangalore             1
# Pune                  1
# Jaipur                1
# Mysore                1
# Thrissur              1
# Bhopal                1
# Chennai               1
# Patna                 1
# Nagpur                1
# Dehradun              1
# Chandigarh            1
# Surat                 1
# Allahabad             1
# Kanpur                1
# Indore                1
# Name: count, dtype: int64

# %%
c=df[df['department']=='Electronics']
print(len(c))
# Out:
# 6

# %%
s_student = df[(df['city'] == 'Chennai') | (df['city'] == 'Mumbai')]
display(s_student[['name', 'city', 'math_score', 'science_score', 'english_score', 'programming_score']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4598/266497540.py in <cell line: 0>()
# ----> 1 s_student=df[df['city']=='Chennai'and'Mumbai']
#       2 print(df['math_score'].value_counts())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
s_student=df[(df['city']=='Chennai')|(df['city']=='Mumbai')]
print(s_student[['name','city','programming_score']])
# Out:
#             name     city  programming_score
# 0   Aarav Sharma   Mumbai                 91
# 10   Vikram Iyer  Chennai                 72

# %%
df['total']=df['math_score']+df['english_score']+df['programming_score']+df['science_score']
top=df.loc[df['total'].idxmax()]
print(top)
min=df.loc[df['total'].idxmin()]
print(min)
# Out:
# student_id                           1010
# name                           Ananya Das
# age                                    19
# gender                             Female
# department               Computer Science
# semester                                2
# math_score                             95
# science_score                          89
# english_score                          90
# programming_score                      97
# attendance_percentage                  98
# city                              Kolkata
# admission_year                       2023
# total                                 371
# Name: 9, dtype: object
# student_id                       1017
# name                     Manoj Pandey
# age                                21
# gender                           Male
# department                      Civil
# semester                            2
# math_score                         56
# science_score                      61
# ...
